# %%
# import libraries/modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read into data/dataset
movie = pd.read_csv('D:/ML/Pandas/data/movie.csv')
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
# Accessing the main DataFrame components
index = movie.index
index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
columns = movie.columns
columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
values = movie.values
values
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %%
index.values
# Out:
# array([   0,    1,    2, ..., 4913, 4914, 4915], dtype=int64)

# %%
columns.values
# Out:
# array(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes',
#        'actor_2_name', 'actor_1_facebook_likes', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users',
#        'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes'], dtype=object)

# %%
# Data types
movie.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
movie.get_dtype_counts()
# Out:
# float64    13
# int64       3
# object     12
# dtype: int64

# %%
# Selecting single columns
movie['genres'].tail(10)
# Out:
# 4906                  Drama|Sci-Fi|Thriller
# 4907                               Thriller
# 4908    Action|Crime|Drama|Romance|Thriller
# 4909                            Crime|Drama
# 4910                           Comedy|Drama
# 4911                           Comedy|Drama
# 4912           Crime|Drama|Mystery|Thriller
# 4913                  Drama|Horror|Thriller
# 4914                   Comedy|Drama|Romance
# 4915                            Documentary
# Name: genres, dtype: object

# %%
movie.genres.head(15)
# Out:
# 0                       Action|Adventure|Fantasy|Sci-Fi
# 1                              Action|Adventure|Fantasy
# 2                             Action|Adventure|Thriller
# 3                                       Action|Thriller
# 4                                           Documentary
# 5                               Action|Adventure|Sci-Fi
# 6                              Action|Adventure|Romance
# 7     Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 8                               Action|Adventure|Sci-Fi
# 9                      Adventure|Family|Fantasy|Mystery
# 10                              Action|Adventure|Sci-Fi
# 11                              Action|Adventure|Sci-Fi
# 12                                     Action|Adventure
# 13                             Action|Adventure|Fantasy
# 14                             Action|Adventure|Western
# Name: genres, dtype: object

# %%
type(movie.genres)
# Out:
# pandas.core.series.Series

# %%
movie['genres'].to_frame().head(15)
# Out:
#                                                genres
# 0                     Action|Adventure|Fantasy|Sci-Fi
# 1                            Action|Adventure|Fantasy
# 2                           Action|Adventure|Thriller
# 3                                     Action|Thriller
# 4                                         Documentary
# 5                             Action|Adventure|Sci-Fi
# 6                            Action|Adventure|Romance
# 7   Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 8                             Action|Adventure|Sci-Fi
# 9                    Adventure|Family|Fantasy|Mystery
# 10                            Action|Adventure|Sci-Fi
# 11                            Action|Adventure|Sci-Fi
# 12                                   Action|Adventure
# 13                           Action|Adventure|Fantasy
# 14                           Action|Adventure|Western

# %%
# Calling Series methods
set(dir(movie['genres']))
# Out:
# {'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
# ...

# %%
len(set(dir(movie['genres'])))
# Out:
# 451

# %%
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
director = movie['director_name']
facebook = movie['director_facebook_likes']
director.head()
facebook.head()
# Out:
# 0        0.0
# 1      563.0
# 2        0.0
# 3    22000.0
# 4      131.0
# Name: director_facebook_likes, dtype: float64

# %%
director.value_counts().head(10)
# Out:
# Steven Spielberg     26
# Woody Allen          22
# Martin Scorsese      20
# Clint Eastwood       20
# Spike Lee            16
# Ridley Scott         16
# Steven Soderbergh    15
# Renny Harlin         15
# Oliver Stone         14
# Tim Burton           14
# Name: director_name, dtype: int64

# %%
facebook.value_counts().head(7)
# Out:
# 0.0     877
# 3.0      69
# 6.0      66
# 2.0      63
# 7.0      63
# 4.0      60
# 11.0     57
# Name: director_facebook_likes, dtype: int64

# %%
director.size
# Out:
# 4916

# %%
facebook.shape
# Out:
# (4916,)

# %%
facebook.count()
# Out:
# 4814

# %%
facebook.min()
# Out:
# 0.0

# %%
facebook.max()
# Out:
# 23000.0

# %%
facebook.mean()
# Out:
# 691.01454092231

# %%
facebook.std()
# Out:
# 2832.954124710823

# %%
facebook.median()
# Out:
# 48.0

# %%
facebook.sum()
# Out:
# 3326544.0

# %%
facebook.describe()
# Out:
# count     4814.000000
# mean       691.014541
# std       2832.954125
# min          0.000000
# 25%          7.000000
# 50%         48.000000
# 75%        189.750000
# max      23000.000000
# Name: director_facebook_likes, dtype: float64

# %%
facebook.isnull().head(15)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# Name: director_facebook_likes, dtype: bool

# %%
facebook_filled = facebook.fillna(0)

# %%
facebook_filled.count()
# Out:
# 4916

# %%
facebook_dropped = facebook.dropna()
facebook_dropped.count()
# Out:
# 4814

# %%
director.value_counts(normalize = True).head(10)
# Out:
# Steven Spielberg     0.005401
# Woody Allen          0.004570
# Martin Scorsese      0.004155
# Clint Eastwood       0.004155
# Spike Lee            0.003324
# Ridley Scott         0.003324
# Steven Soderbergh    0.003116
# Renny Harlin         0.003116
# Oliver Stone         0.002908
# Tim Burton           0.002908
# Name: director_name, dtype: float64

# %%
director.hasnans
# Out:
# True

# %%
director.notnull().tail(15)
# Out:
# 4901     True
# 4902     True
# 4903     True
# 4904     True
# 4905     True
# 4906     True
# 4907     True
# 4908     True
# 4909     True
# 4910     True
# 4911     True
# 4912    False
# 4913     True
# 4914     True
# 4915     True
# Name: director_name, dtype: bool

# %%
# operators on a Series
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
imdb_score = movie.imdb_score
imdb_score.head()
# Out:
# 0    7.9
# 1    7.1
# 2    6.8
# 3    8.5
# 4    7.1
# Name: imdb_score, dtype: float64

# %%
(imdb_score + 2).head(10)
# Out:
# 0     9.9
# 1     9.1
# 2     8.8
# 3    10.5
# 4     9.1
# 5     8.6
# 6     8.2
# 7     9.8
# 8     9.5
# 9     9.5
# Name: imdb_score, dtype: float64

# %%
(imdb_score // 2).head()
# Out:
# 0    3.0
# 1    3.0
# 2    3.0
# 3    4.0
# 4    3.0
# Name: imdb_score, dtype: float64

# %%
(imdb_score ** 2).head()
# Out:
# 0    62.41
# 1    50.41
# 2    46.24
# 3    72.25
# 4    50.41
# Name: imdb_score, dtype: float64

# %%
(director != 'James Cameron').tail()
# Out:
# 4911    True
# 4912    True
# 4913    True
# 4914    True
# 4915    True
# Name: director_name, dtype: bool

# %%
facebook.add(3).tail(15)
# Out:
# 4901     21.0
# 4902     65.0
# 4903      8.0
# 4904    123.0
# 4905      6.0
# 4906    294.0
# 4907      3.0
# 4908      3.0
# 4909      5.0
# 4910      3.0
# 4911      5.0
# 4912      NaN
# 4913      3.0
# 4914      3.0
# 4915     19.0
# Name: director_facebook_likes, dtype: float64

# %%
facebook.add(3).mul(15)
# Out:
# 0           45.0
# 1         8490.0
# 2           45.0
# 3       330045.0
# 4         2010.0
# 5         7170.0
# 6           45.0
# 7          270.0
# 8           45.0
# 9         4275.0
# 10          45.0
# 11          45.0
# 12        5970.0
# 13        8490.0
# 14        8490.0
# 15          45.0
# 16        1245.0
# 17          45.0
# 18        3825.0
# 19        2865.0
# 20          45.0
# 21        7005.0
# 22          45.0
# 23          45.0
# 24        1980.0
# 25          45.0
# 26          45.0
# 27        1455.0
# 28        8025.0
# 29        5520.0
#           ...
# 4886        90.0
# 4887     13425.0
# 4888        45.0
# 4889        45.0
# 4890      2115.0
# 4891      8880.0
# 4892      2415.0
# 4893       165.0
# 4894      2400.0
# 4895        45.0
# 4896       615.0
# 4897      1410.0
# 4898        45.0
# 4899      1650.0
# 4900      6000.0
# 4901       315.0
# 4902       975.0
# 4903       120.0
# 4904      1845.0
# 4905        90.0
# 4906      4410.0
# ...

# %%
imdb_score.floordiv(7).head(15)
# Out:
# 0     1.0
# 1     1.0
# 2     0.0
# 3     1.0
# 4     1.0
# 5     0.0
# 6     0.0
# 7     1.0
# 8     1.0
# 9     1.0
# 10    0.0
# 11    0.0
# 12    0.0
# 13    1.0
# 14    0.0
# Name: imdb_score, dtype: float64

# %%
imdb_score.gt(7).head(15)
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4      True
# 5     False
# 6     False
# 7      True
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# Name: imdb_score, dtype: bool

# %%
imdb_score.lt(7).head(15)
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13    False
# 14     True
# Name: imdb_score, dtype: bool

# %%
director.eq('James Cameron')
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26       True
# 27      False
# 28      False
# 29      False
#         ...
# 4886    False
# 4887    False
# 4888    False
# 4889    False
# 4890    False
# 4891    False
# 4892    False
# 4893    False
# 4894    False
# 4895    False
# 4896    False
# 4897    False
# 4898    False
# 4899    False
# 4900    False
# 4901    False
# 4902    False
# 4903    False
# 4904    False
# 4905    False
# 4906    False
# 4907    False
# 4908    False
# 4909    False
# 4910    False
# 4911    False
# 4912    False
# 4913    False
# 4914    False
# 4915    False
# ...

# %%
# Chaining Series methods together
movie.head(8)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
# 6  Color          Sam Raimi                   392.0     156.0
# 7  Color       Nathan Greno                   324.0     100.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# ...

# %%
facebook.isnull().sum()
# Out:
# 102

# %%
facebook.fillna(0).astype(float).tail(15)
# Out:
# 4901     18.0
# 4902     62.0
# 4903      5.0
# 4904    120.0
# 4905      3.0
# 4906    291.0
# 4907      0.0
# 4908      0.0
# 4909      2.0
# 4910      0.0
# 4911      2.0
# 4912      0.0
# 4913      0.0
# 4914      0.0
# 4915     16.0
# Name: director_facebook_likes, dtype: float64

# %%
# using index
movie2 = movie.set_index('movie_title')
movie2.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
movie = pd.read_csv('D:/ML/Pandas/data/movie.csv',index_col = 'movie_title')
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
movie2.reset_index()
movie2.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
# Renaming row and column names
idx_rename = {'Avatar':'Ratava', 'Spectre': 'Ertceps'}
col_rename = {'director_name':'Director Name',
'num_critic_for_reviews': 'Critical Reviews'}
movie_renamed = movie.rename(index=idx_rename,
columns=col_rename)
movie_renamed.head()
# Out:
#                                             color      Director Name  \
# movie_title
# Ratava                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Ertceps                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             Critical Reviews  duration  \
# movie_title
# Ratava                                                 723.0     178.0
# Pirates of the Caribbean: At World's End               302.0     169.0
# Ertceps                                                602.0     148.0
# The Dark Knight Rises                                  813.0     164.0
# Star Wars: Episode VII - The Force Awakens               NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# ...

# %%
index = movie.index
columns = movie.columns
index_list = index.tolist()
column_list = columns.tolist()
index_list[0] = 'Ratava'
index_list[2] = 'Ertceps'
column_list[1] = 'Director Name'
column_list[2] = 'Critical Reviews'
index_list
# Out:
# ['Ratava',
#  "Pirates of the Caribbean: At World's End",
#  'Ertceps',
#  'The Dark Knight Rises',
#  'Star Wars: Episode VII - The Force Awakens',
#  'John Carter',
#  'Spider-Man 3',
#  'Tangled',
#  'Avengers: Age of Ultron',
#  'Harry Potter and the Half-Blood Prince',
#  'Batman v Superman: Dawn of Justice',
#  'Superman Returns',
#  'Quantum of Solace',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'The Lone Ranger',
#  'Man of Steel',
#  'The Chronicles of Narnia: Prince Caspian',
#  'The Avengers',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Men in Black 3',
#  'The Hobbit: The Battle of the Five Armies',
#  'The Amazing Spider-Man',
#  'Robin Hood',
#  'The Hobbit: The Desolation of Smaug',
#  'The Golden Compass',
#  'King Kong',
#  'Titanic',
#  'Captain America: Civil War',
#  'Battleship',
#  'Jurassic World',
#  'Skyfall',
#  'Spider-Man 2',
#  'Iron Man 3',
#  'Alice in Wonderland',
#  'X-Men: The Last Stand',
#  'Monsters University',
# ...

# %%
column_list
# Out:
# ['color',
#  'Director Name',
#  'Critical Reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes']

# %%
# Creating and deleting columns
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
movie['has_seen'] = 0
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
movie['actor_director_facebook_likes'] = \
(movie['actor_1_facebook_likes'] +
movie['actor_2_facebook_likes'] +
movie['actor_3_facebook_likes'] +
movie['director_facebook_likes'])
movie['actor_director_facebook_likes'] = \
movie['actor_director_facebook_likes'].fillna(0)
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
movie['is_cast_likes_more'] = \
(movie['cast_total_facebook_likes'] >=
movie['actor_director_facebook_likes'])
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
# Selecting multiple DataFrame columns
movie_actor_director = movie[['actor_1_name', 'actor_2_name',
'actor_3_name', 'director_name']]
movie_actor_director.head()
# Out:
#                                                actor_1_name      actor_2_name  \
# movie_title
# Avatar                                          CCH Pounder  Joel David Moore
# Pirates of the Caribbean: At World's End        Johnny Depp     Orlando Bloom
# Spectre                                     Christoph Waltz      Rory Kinnear
# The Dark Knight Rises                             Tom Hardy    Christian Bale
# Star Wars: Episode VII - The Force Awakens      Doug Walker        Rob Walker
#
#                                                     actor_3_name  \
# movie_title
# Avatar                                                 Wes Studi
# Pirates of the Caribbean: At World's End          Jack Davenport
# Spectre                                         Stephanie Sigman
# The Dark Knight Rises                       Joseph Gordon-Levitt
# Star Wars: Episode VII - The Force Awakens                   NaN
#
#                                                 director_name
# movie_title
# ...

# %%
movie['director_name'].to_frame().head()
# Out:
#                                                 director_name
# movie_title
# Avatar                                          James Cameron
# Pirates of the Caribbean: At World's End       Gore Verbinski
# Spectre                                            Sam Mendes
# The Dark Knight Rises                       Christopher Nolan
# Star Wars: Episode VII - The Force Awakens        Doug Walker

# %%
movie[['director_name']].head()
# Out:
#                                                 director_name
# movie_title
# Avatar                                          James Cameron
# Pirates of the Caribbean: At World's End       Gore Verbinski
# Spectre                                            Sam Mendes
# The Dark Knight Rises                       Christopher Nolan
# Star Wars: Episode VII - The Force Awakens        Doug Walker

# %%
movie.director_name.to_frame().head()
# Out:
#                                                 director_name
# movie_title
# Avatar                                          James Cameron
# Pirates of the Caribbean: At World's End       Gore Verbinski
# Spectre                                            Sam Mendes
# The Dark Knight Rises                       Christopher Nolan
# Star Wars: Episode VII - The Force Awakens        Doug Walker

# %%
# Selecting columns with methods
movie.get_dtype_counts()
# Out:
# object     11
# float64    13
# int64       4
# bool        1
# dtype: int64

# %%
movie.select_dtypes(include=['int']).head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [Avatar, Pirates of the Caribbean: At World's End, Spectre, The Dark Knight Rises, Star Wars: Episode VII - The Force Awakens]

# %%
movie.select_dtypes(include=['number']).head()
# Out:
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
# ...

# %%
movie.filter(like='facebook').head()
# Out:
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                             actor_1_facebook_likes  \
# movie_title
# ...

# %%
movie.filter(regex='\d').head()
# Out:
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# ...

# %%
# Ordering column names
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
movie.columns.to_frame()
# Out:
#                                                    0
# color                                          color
# director_name                          director_name
# num_critic_for_reviews        num_critic_for_reviews
# duration                                    duration
# director_facebook_likes      director_facebook_likes
# actor_3_facebook_likes        actor_3_facebook_likes
# actor_2_name                            actor_2_name
# actor_1_facebook_likes        actor_1_facebook_likes
# gross                                          gross
# genres                                        genres
# actor_1_name                            actor_1_name
# num_voted_users                      num_voted_users
# cast_total_facebook_likes  cast_total_facebook_likes
# actor_3_name                            actor_3_name
# facenumber_in_poster            facenumber_in_poster
# plot_keywords                          plot_keywords
# movie_imdb_link                      movie_imdb_link
# ...

# %%
disc_core = ['title_year',
'content_rating', 'genres']
disc_people = ['director_name', 'actor_1_name',
'actor_2_name', 'actor_3_name']
disc_other = ['color', 'country', 'language',
'plot_keywords', 'movie_imdb_link']
cont_fb = ['director_facebook_likes', 'actor_1_facebook_likes',
'actor_2_facebook_likes', 'actor_3_facebook_likes',
'cast_total_facebook_likes', 'movie_facebook_likes']
cont_finance = ['budget', 'gross']
cont_num_reviews = ['num_voted_users', 'num_user_for_reviews',
'num_critic_for_reviews']
cont_other = ['imdb_score', 'duration',
'aspect_ratio', 'facenumber_in_poster']

# %%
new_col_order = disc_core + disc_people + \
disc_other + cont_fb + \
cont_finance + cont_num_reviews + \
cont_other
set(movie.columns) == set(new_col_order)
# Out:
# False

# %%
movie2 = movie[new_col_order]
movie2.head()
# Out:
#                                             title_year content_rating  \
# movie_title
# Avatar                                          2009.0          PG-13
# Pirates of the Caribbean: At World's End        2007.0          PG-13
# Spectre                                         2015.0          PG-13
# The Dark Knight Rises                           2012.0          PG-13
# Star Wars: Episode VII - The Force Awakens         NaN            NaN
#
#                                                                      genres  \
# movie_title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
#
# ...

# %%
# Operating on the entire DataFrame
movie.shape
# Out:
# (4916, 29)

# %%
movie.size
# Out:
# 142564

# %%
movie.ndim
# Out:
# 2

# %%
len(movie)
# Out:
# 4916

# %%
movie.count()
# Out:
# color                        4897
# director_name                4814
# num_critic_for_reviews       4867
# duration                     4901
# director_facebook_likes      4814
# actor_3_facebook_likes       4893
# actor_2_name                 4903
# actor_1_facebook_likes       4909
# gross                        4054
# genres                       4916
# actor_1_name                 4909
# num_voted_users              4916
# cast_total_facebook_likes    4916
# actor_3_name                 4893
# facenumber_in_poster         4903
# plot_keywords                4764
# movie_imdb_link              4916
# num_user_for_reviews         4895
# language                     4904
# country                      4911
# content_rating               4616
# budget                       4432
# title_year                   4810
# actor_2_facebook_likes       4903
# imdb_score                   4916
# aspect_ratio                 4590
# movie_facebook_likes         4916
# ...

# %%
movie.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 25%                 49.000000    93.000000                 7.000000
# 50%                108.000000   103.000000                48.000000
# 75%                191.000000   118.000000               189.750000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
# Chaining DataFrame methods together
movie.isnull().sum().head()
# Out:
# color                       19
# director_name              102
# num_critic_for_reviews      49
# duration                    15
# director_facebook_likes    102
# dtype: int64

# %%
movie.notnull().sum().sum()
# Out:
# 139910

# %%
movie.isnull().get_dtype_counts()
# Out:
# bool    29
# dtype: int64

# %%
movie.select_dtypes(['object']).fillna('').min()
# Out:
# color
# director_name
# actor_2_name
# genres                                                        Action
# actor_1_name
# actor_3_name
# plot_keywords
# movie_imdb_link    http://www.imdb.com/title/tt0006864/?ref_=fn_t...
# language
# country
# content_rating
# dtype: object

# %%
# Working with operators on a DataFrame
college = pd.read_csv('D:/ML/Pandas_tut/data/college.csv',index_col = 'INSTNM' )
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# ...

# %%
college_ugds_ = college.filter(like='UGDS_')
college_ugds_.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
(college_ugds_ + .00501).head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                0.03831     0.94031    0.01051
# University of Alabama at Birmingham     0.59721     0.26501    0.03331
# Amridge University                      0.30401     0.42421    0.01191
# University of Alabama in Huntsville     0.70381     0.13051    0.04321
# Alabama State University                0.02081     0.92581    0.01711
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                0.00691    0.00741    0.00691
# University of Alabama at Birmingham     0.05681    0.00721    0.00571
# Amridge University                      0.00841    0.00501    0.00501
# University of Alabama in Huntsville     0.04261    0.01931    0.00521
# Alabama State University                0.00691    0.00601    0.00561
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
((college_ugds_ + .00501) // .01).head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                    3.0        94.0        1.0
# University of Alabama at Birmingham        59.0        26.0        3.0
# Amridge University                         30.0        42.0        1.0
# University of Alabama in Huntsville        70.0        13.0        4.0
# Alabama State University                    2.0        92.0        1.0
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                    0.0        0.0        0.0
# University of Alabama at Birmingham         5.0        0.0        0.0
# Amridge University                          0.0        0.0        0.0
# University of Alabama in Huntsville         4.0        1.0        0.0
# Alabama State University                    0.0        0.0        0.0
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
college_ugds_op_round = (college_ugds_ + .00501) // .01 / 100
college_ugds_op_round.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                   0.03        0.94       0.01
# University of Alabama at Birmingham        0.59        0.26       0.03
# Amridge University                         0.30        0.42       0.01
# University of Alabama in Huntsville        0.70        0.13       0.04
# Alabama State University                   0.02        0.92       0.01
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                   0.00       0.00        0.0
# University of Alabama at Birmingham        0.05       0.00        0.0
# Amridge University                         0.00       0.00        0.0
# University of Alabama in Huntsville        0.04       0.01        0.0
# Alabama State University                   0.00       0.00        0.0
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
college_ugds_round = (college_ugds_ + .00001).round(2)
college_ugds_round.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                   0.03        0.94       0.01
# University of Alabama at Birmingham        0.59        0.26       0.03
# Amridge University                         0.30        0.42       0.01
# University of Alabama in Huntsville        0.70        0.13       0.04
# Alabama State University                   0.02        0.92       0.01
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                   0.00       0.00        0.0
# University of Alabama at Birmingham        0.05       0.00        0.0
# Amridge University                         0.00       0.00        0.0
# University of Alabama in Huntsville        0.04       0.01        0.0
# Alabama State University                   0.00       0.00        0.0
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
college_ugds_round.equals(college_ugds_op_round)
# Out:
# True

# %%
college_ugds_ == .0019
# Out:
#                                                     UGDS_WHITE  UGDS_BLACK  \
# INSTNM
# Alabama A & M University                                 False       False
# University of Alabama at Birmingham                      False       False
# Amridge University                                       False       False
# University of Alabama in Huntsville                      False       False
# Alabama State University                                 False       False
# The University of Alabama                                False       False
# Central Alabama Community College                        False       False
# Athens State University                                  False       False
# Auburn University at Montgomery                          False       False
# Auburn University                                        False       False
# Birmingham Southern College                              False       False
# ...

# %%
# Data Analysis
# metadata and univariate descriptive statistics
college.shape
# Out:
# (7535, 26)

# %%
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7535 entries, Alabama A & M University to Excel Learning Center-San Antonio South
# Data columns (total 26 columns):
# CITY                  7535 non-null object
# STABBR                7535 non-null object
# HBCU                  7164 non-null float64
# MENONLY               7164 non-null float64
# WOMENONLY             7164 non-null float64
# RELAFFIL              7535 non-null int64
# SATVRMID              1185 non-null float64
# SATMTMID              1196 non-null float64
# DISTANCEONLY          7164 non-null float64
# UGDS                  6874 non-null float64
# UGDS_WHITE            6874 non-null float64
# UGDS_BLACK            6874 non-null float64
# UGDS_HISP             6874 non-null float64
# UGDS_ASIAN            6874 non-null float64
# UGDS_AIAN             6874 non-null float64
# UGDS_NHPI             6874 non-null float64
# UGDS_2MOR             6874 non-null float64
# UGDS_NRA              6874 non-null float64
# ...

# %%
college.describe(include=[np.number]).T
# Out:
#                count         mean          std    min         25%        50%  \
# HBCU          7164.0     0.014238     0.118478    0.0    0.000000    0.00000
# MENONLY       7164.0     0.009213     0.095546    0.0    0.000000    0.00000
# WOMENONLY     7164.0     0.005304     0.072642    0.0    0.000000    0.00000
# RELAFFIL      7535.0     0.190975     0.393096    0.0    0.000000    0.00000
# SATVRMID      1185.0   522.819409    68.578862  290.0  475.000000  510.00000
# SATMTMID      1196.0   530.765050    73.469767  310.0  482.000000  520.00000
# DISTANCEONLY  7164.0     0.005583     0.074519    0.0    0.000000    0.00000
# UGDS          6874.0  2356.837940  5474.275871    0.0  117.000000  412.50000
# UGDS_WHITE    6874.0     0.510207     0.286958    0.0    0.267500    0.55570
# UGDS_BLACK    6874.0     0.189997     0.224587    0.0    0.036125    0.10005
# UGDS_HISP     6874.0     0.161635     0.221854    0.0    0.027600    0.07140
# ...

# %%
college.describe(include=[np.object, pd.Categorical]).T
# Out:
#                    count unique                top  freq
# CITY                7535   2514           New York    87
# STABBR              7535     59                 CA   773
# MD_EARN_WNE_P10     6413    598  PrivacySuppressed   822
# GRAD_DEBT_MDN_SUPP  7503   2038  PrivacySuppressed  1510

# %%
# Reducing memory by changing data types
different_cols = ['RELAFFIL', 'SATMTMID', 'CURROPER', 'STABBR']
col2 = college.loc[:, different_cols]
col2.head()
# Out:
#                                      RELAFFIL  SATMTMID  CURROPER STABBR
# INSTNM
# Alabama A & M University                    0     420.0         1     AL
# University of Alabama at Birmingham         0     565.0         1     AL
# Amridge University                          1       NaN         1     AL
# University of Alabama in Huntsville         0     590.0         1     AL
# Alabama State University                    0     430.0         1     AL

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# ...

# %%
col2.dtypes
# Out:
# RELAFFIL      int64
# SATMTMID    float64
# CURROPER      int64
# INSTNM      float64
# STABBR       object
# dtype: object

# %%
original_mem = col2.memory_usage(deep=True)
original_mem
# Out:
# Index       660240
# RELAFFIL     60280
# SATMTMID     60280
# CURROPER     60280
# INSTNM       60280
# STABBR      444565
# dtype: int64

# %%
col2['RELAFFIL'] = col2['RELAFFIL'].astype(np.int8)
col2.dtypes
# Out:
# RELAFFIL       int8
# SATMTMID    float64
# CURROPER      int64
# INSTNM      float64
# STABBR       object
# dtype: object

# %%
college[different_cols].memory_usage(deep=True)
# Out:
# Index       660240
# RELAFFIL     60280
# SATMTMID     60280
# CURROPER     60280
# STABBR      444565
# dtype: int64

# %%
col2.select_dtypes(include=['object']).nunique()
# Out:
# STABBR    59
# dtype: int64

# %%
col2['STABBR'] = col2['STABBR'].astype('category')
col2.dtypes
# Out:
# RELAFFIL       int64
# SATMTMID     float64
# CURROPER       int64
# STABBR      category
# dtype: object

# %%
new_mem = col2.memory_usage(deep=True)
new_mem
# Out:
# Index       660240
# RELAFFIL     60280
# SATMTMID     60280
# CURROPER     60280
# STABBR       13576
# dtype: int64

# %%
# Selecting the smallest of the largest
movie2 = movie[['imdb_score', 'budget']]
movie2.head()
# Out:
#                                             imdb_score       budget
# movie_title
# Avatar                                             7.9  237000000.0
# Pirates of the Caribbean: At World's End           7.1  300000000.0
# Spectre                                            6.8  245000000.0
# The Dark Knight Rises                              8.5  250000000.0
# Star Wars: Episode VII - The Force Awakens         7.1          NaN

# %%
movie2.nlargest(100, 'imdb_score').head()
# Out:
#                           imdb_score      budget
# movie_title
# Towering Inferno                 9.5         NaN
# The Shawshank Redemption         9.3  25000000.0
# The Godfather                    9.2   6000000.0
# Dekalog                          9.1         NaN
# Kickboxer: Vengeance             9.1  17000000.0

# %%
movie2.nlargest(100, 'imdb_score').nsmallest(5, 'budget')
# Out:
#                       imdb_score    budget
# movie_title
# Butterfly Girl               8.7  180000.0
# Children of Heaven           8.5  180000.0
# 12 Angry Men                 8.9  350000.0
# A Separation                 8.4  500000.0
# The Other Dream Team         8.4  500000.0

# %%
# Selecting the largest of each group by sorting
movie3 = movie[['imdb_score', 'title_year']]
movie3.head()
# Out:
#                                             imdb_score  title_year
# movie_title
# Avatar                                             7.9      2009.0
# Pirates of the Caribbean: At World's End           7.1      2007.0
# Spectre                                            6.8      2015.0
# The Dark Knight Rises                              8.5      2012.0
# Star Wars: Episode VII - The Force Awakens         7.1         NaN

# %%
movie3.sort_values(['title_year','imdb_score'], ascending=False).head()
# Out:
#                              imdb_score  title_year
# movie_title
# Kickboxer: Vengeance                9.1      2016.0
# A Beginner's Guide to Snuff         8.7      2016.0
# Airlift                             8.5      2016.0
# Captain America: Civil War          8.2      2016.0
# Godzilla Resurgence                 8.2      2016.0

# %%
movie_top_year = movie3.drop_duplicates(subset='title_year')
movie_top_year.head()
# Out:
#                                             imdb_score  title_year
# movie_title
# Avatar                                             7.9      2009.0
# Pirates of the Caribbean: At World's End           7.1      2007.0
# Spectre                                            6.8      2015.0
# The Dark Knight Rises                              8.5      2012.0
# Star Wars: Episode VII - The Force Awakens         7.1         NaN

# %%
movie4 = movie[['imdb_score', 'budget']]
movie_smallest_largest = movie4.nlargest(100, 'imdb_score') \
.nsmallest(5, 'budget')
movie_smallest_largest
# Out:
#                       imdb_score    budget
# movie_title
# Butterfly Girl               8.7  180000.0
# Children of Heaven           8.5  180000.0
# 12 Angry Men                 8.9  350000.0
# A Separation                 8.4  500000.0
# The Other Dream Team         8.4  500000.0

# %%
movie4.sort_values('imdb_score', ascending=False).head(20)
# Out:
#                                                    imdb_score       budget
# movie_title
# Towering Inferno                                          9.5          NaN
# The Shawshank Redemption                                  9.3   25000000.0
# The Godfather                                             9.2    6000000.0
# Dekalog                                                   9.1          NaN
# Kickboxer: Vengeance                                      9.1   17000000.0
# Fargo                                                     9.0          NaN
# The Godfather: Part II                                    9.0   13000000.0
# The Dark Knight                                           9.0  185000000.0
# Schindler's List                                          8.9   22000000.0
# The Lord of the Rings: The Return of the King             8.9   94000000.0
# Pulp Fiction                                              8.9    8000000.0
# ...

# %%
import pandas_datareader as pdr
tsla = pdr.DataReader('tsla', data_source='google',start='2017-1-1')
tsla.head()
# Out:
# ---------------------------------------------------------------------------
# ImmediateDeprecationError                 Traceback (most recent call last)
# <ipython-input-186-85bd17835590> in <module>
#       1 import pandas_datareader as pdr
# ----> 2 tsla = pdr.DataReader('tsla', data_source='google',start='2017-1-1')
#       3 tsla.head()
#
# D:\ML\anaconda\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     314                                  chunksize=25,
#     315                                  retry_count=retry_count, pause=pause,
# --> 316                                  session=session).read()
#     317
#     318     elif data_source == "iex":
#
# D:\ML\anaconda\lib\site-packages\pandas_datareader\google\daily.py in __init__(self, symbols, start, end, retry_count, pause, session, chunksize)
#      34     def __init__(self, symbols=None, start=None, end=None, retry_count=3,
# ...

# %%
# Selecting Subsets of Data
city = college['CITY']
city.head()
# Out:
# INSTNM
# Alabama A & M University                   Normal
# University of Alabama at Birmingham    Birmingham
# Amridge University                     Montgomery
# University of Alabama in Huntsville    Huntsville
# Alabama State University               Montgomery
# Name: CITY, dtype: object

# %%
city.iloc[1]
# Out:
# 'Birmingham'

# %%
city.iloc[[1,47,2]]
# Out:
# INSTNM
# University of Alabama at Birmingham    Birmingham
# Selma University                            Selma
# Amridge University                     Montgomery
# Name: CITY, dtype: object

# %%
city.iloc[[4:50:10]]
# Out:
#   File "<ipython-input-213-eedc6cc6a07e>", line 1
#     city.iloc[[4:50:10]]
#                 ^
# SyntaxError: invalid syntax

# %%
city.loc['Reid State Technical College']
# Out:
# 'Evergreen'

# %%
city.loc['Alabama State University':'Reid State Technical College':5]
# Out:
# INSTNM
# Alabama State University                           Montgomery
# Auburn University                                      Auburn
# Enterprise State Community College                 Enterprise
# George C Wallace State Community College-Dothan        Dothan
# Heritage Christian University                        Florence
# John C Calhoun State Community College                 Tanner
# Marion Military Institute                              Marion
# University of North Alabama                          Florence
# Reid State Technical College                        Evergreen
# Name: CITY, dtype: object

# %%
city.iloc[[5]].to_frame()
# Out:
#                                  CITY
# INSTNM
# The University of Alabama  Tuscaloosa

# %%
# Selecting DataFrame rows
college.head(8)
# Out:
#                                                CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                     Normal     AL   1.0      0.0
# University of Alabama at Birmingham      Birmingham     AL   0.0      0.0
# Amridge University                       Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville      Huntsville     AL   0.0      0.0
# Alabama State University                 Montgomery     AL   1.0      0.0
# The University of Alabama                Tuscaloosa     AL   0.0      0.0
# Central Alabama Community College    Alexander City     AL   0.0      0.0
# Athens State University                      Athens     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# ...

# %%
college.iloc[[4]]
# Out:
#                                 CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# INSTNM
# Alabama State University  Montgomery     AL   1.0      0.0        0.0
#
#                           RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY    UGDS  \
# INSTNM
# Alabama State University         0     425.0     430.0           0.0  4811.0
#
#                                  ...          UGDS_2MOR  UGDS_NRA  UGDS_UNKN  \
# INSTNM                           ...
# Alabama State University         ...             0.0098    0.0243     0.0137
#
#                           PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# Alabama State University    0.0892         1   0.7347    0.7554    0.127
#
#                           MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama State University            26600             33118.5
#
# [1 rows x 26 columns]

# %%
college.loc[['Alabama State University']]
# Out:
#                                 CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# INSTNM
# Alabama State University  Montgomery     AL   1.0      0.0        0.0
#
#                           RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY    UGDS  \
# INSTNM
# Alabama State University         0     425.0     430.0           0.0  4811.0
#
#                                  ...          UGDS_2MOR  UGDS_NRA  UGDS_UNKN  \
# INSTNM                           ...
# Alabama State University         ...             0.0098    0.0243     0.0137
#
#                           PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# Alabama State University    0.0892         1   0.7347    0.7554    0.127
#
#                           MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama State University            26600             33118.5
#
# [1 rows x 26 columns]

# %%
college.iloc[[0, 10, 2]]
# Out:
#                                    CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# INSTNM
# Alabama A & M University         Normal     AL   1.0      0.0        0.0
# Birmingham Southern College  Birmingham     AL   0.0      0.0        0.0
# Amridge University           Montgomery     AL   0.0      0.0        0.0
#
#                              RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# INSTNM
# Alabama A & M University            0     424.0     420.0           0.0
# Birmingham Southern College         1     560.0     560.0           0.0
# Amridge University                  1       NaN       NaN           1.0
#
#                                UGDS         ...          UGDS_2MOR  UGDS_NRA  \
# INSTNM                                      ...
# Alabama A & M University     4206.0         ...             0.0000    0.0059
# Birmingham Southern College  1180.0         ...             0.0051    0.0000
# Amridge University            291.0         ...             0.0000    0.0000
#
# ...

# %%
labels = ['University of Alaska Anchorage','International Academy of Hair Design','University of Alabama in Huntsville']
college.loc[labels]
# Out:
#                                             CITY STABBR  HBCU  MENONLY  \
# INSTNM
# University of Alaska Anchorage         Anchorage     AK   0.0      0.0
# International Academy of Hair Design       Tempe     AZ   0.0      0.0
# University of Alabama in Huntsville   Huntsville     AL   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# University of Alaska Anchorage              0.0         0       NaN       NaN
# International Academy of Hair Design        0.0         0       NaN       NaN
# University of Alabama in Huntsville         0.0         0     595.0     590.0
#
#                                       DISTANCEONLY     UGDS  \
# INSTNM
# University of Alaska Anchorage                 0.0  12865.0
# International Academy of Hair Design           0.0    188.0
# University of Alabama in Huntsville            0.0   5451.0
#
#                                              ...          UGDS_2MOR  UGDS_NRA  \
# ...

# %%
college.iloc[0:10]
# Out:
#                                                CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                     Normal     AL   1.0      0.0
# University of Alabama at Birmingham      Birmingham     AL   0.0      0.0
# Amridge University                       Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville      Huntsville     AL   0.0      0.0
# Alabama State University                 Montgomery     AL   1.0      0.0
# The University of Alabama                Tuscaloosa     AL   0.0      0.0
# Central Alabama Community College    Alexander City     AL   0.0      0.0
# Athens State University                      Athens     AL   0.0      0.0
# Auburn University at Montgomery          Montgomery     AL   0.0      0.0
# Auburn University                            Auburn     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# ...

# %%
start = 'International Academy of Hair Design'
stop = 'Mesa Community College'
college.loc[start:stop]
# Out:
#                                          CITY STABBR  HBCU  MENONLY  \
# INSTNM
# International Academy of Hair Design    Tempe     AZ   0.0      0.0
# GateWay Community College             Phoenix     AZ   0.0      0.0
# Mesa Community College                   Mesa     AZ   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# International Academy of Hair Design        0.0         0       NaN       NaN
# GateWay Community College                   0.0         0       NaN       NaN
# Mesa Community College                      0.0         0       NaN       NaN
#
#                                       DISTANCEONLY     UGDS  \
# INSTNM
# International Academy of Hair Design           0.0    188.0
# GateWay Community College                      0.0   5211.0
# Mesa Community College                         0.0  19055.0
#
#                                              ...          UGDS_2MOR  UGDS_NRA  \
# ...

# %%
college.iloc[[60, 99, 3]].index.tolist()
# Out:
# ['University of Alaska Anchorage',
#  'International Academy of Hair Design',
#  'University of Alabama in Huntsville']

# %%
# Selecting DataFrame rows and columns simultaneously
college.head(10)
# Out:
#                                                CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                     Normal     AL   1.0      0.0
# University of Alabama at Birmingham      Birmingham     AL   0.0      0.0
# Amridge University                       Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville      Huntsville     AL   0.0      0.0
# Alabama State University                 Montgomery     AL   1.0      0.0
# The University of Alabama                Tuscaloosa     AL   0.0      0.0
# Central Alabama Community College    Alexander City     AL   0.0      0.0
# Athens State University                      Athens     AL   0.0      0.0
# Auburn University at Montgomery          Montgomery     AL   0.0      0.0
# Auburn University                            Auburn     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# ...

# %%
college.iloc[:3,:4]
# Out:
#                                            CITY STABBR  HBCU  MENONLY
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0

# %%
college.loc[:'Auburn University',:'DISTANCEONLY']
# Out:
#                                                CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                     Normal     AL   1.0      0.0
# University of Alabama at Birmingham      Birmingham     AL   0.0      0.0
# Amridge University                       Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville      Huntsville     AL   0.0      0.0
# Alabama State University                 Montgomery     AL   1.0      0.0
# The University of Alabama                Tuscaloosa     AL   0.0      0.0
# Central Alabama Community College    Alexander City     AL   0.0      0.0
# Athens State University                      Athens     AL   0.0      0.0
# Auburn University at Montgomery          Montgomery     AL   0.0      0.0
# Auburn University                            Auburn     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# ...

# %%
college.iloc[:, [0,5,6]].head()
# Out:
#                                            CITY  RELAFFIL  SATVRMID
# INSTNM
# Alabama A & M University                 Normal         0     424.0
# University of Alabama at Birmingham  Birmingham         0     570.0
# Amridge University                   Montgomery         1       NaN
# University of Alabama in Huntsville  Huntsville         0     595.0
# Alabama State University             Montgomery         0     425.0

# %%
college.loc[:, ['WOMENONLY', 'SATVRMID']].head()
# Out:
#                                      WOMENONLY  SATVRMID
# INSTNM
# Alabama A & M University                   0.0     424.0
# University of Alabama at Birmingham        0.0     570.0
# Amridge University                         0.0       NaN
# University of Alabama in Huntsville        0.0     595.0
# Alabama State University                   0.0     425.0

# %%
college.iloc[[50, 100], [4, 15]]
# Out:
#                              WOMENONLY  UGDS_NHPI
# INSTNM
# University of South Alabama        0.0     0.0013
# GateWay Community College          0.0     0.0029

# %%
college.iloc[5, -4]
# Out:
# 0.401

# %%
college.iloc[90:80:-2, 5]
# Out:
# INSTNM
# Empire Beauty School-Flagstaff     0
# Charles of Italy Beauty College    0
# Central Arizona College            0
# University of Arizona              0
# Arizona State University-Tempe     0
# Name: RELAFFIL, dtype: int64

# %%
college.iloc[:10]
# Out:
#                                                CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                     Normal     AL   1.0      0.0
# University of Alabama at Birmingham      Birmingham     AL   0.0      0.0
# Amridge University                       Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville      Huntsville     AL   0.0      0.0
# Alabama State University                 Montgomery     AL   1.0      0.0
# The University of Alabama                Tuscaloosa     AL   0.0      0.0
# Central Alabama Community College    Alexander City     AL   0.0      0.0
# Athens State University                      Athens     AL   0.0      0.0
# Auburn University at Montgomery          Montgomery     AL   0.0      0.0
# Auburn University                            Auburn     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# ...

# %%
# Selecting data with both integers and labels
col_start = college.columns.get_loc('UGDS_WHITE')
col_end = college.columns.get_loc('UGDS_UNKN') + 1
col_start, col_end
# Out:
# (10, 19)

# %%
college.iloc[:5, col_start:col_end]
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
college.ix[10:16, 'UGDS_WHITE':'UGDS_UNKN']
# Out:
# D:\ML\anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#                                           UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Birmingham Southern College                   0.7983      0.1102     0.0195
# Chattahoochee Valley Community College        0.4661      0.4372     0.0492
# Concordia College Alabama                     0.0280      0.8758     0.0373
# South University-Montgomery                   0.3046      0.6054     0.0153
# Enterprise State Community College            0.6408      0.2435     0.0509
# James H Faulkner State Community College      0.6979      0.2259     0.0320
#
#                                           UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# ...
